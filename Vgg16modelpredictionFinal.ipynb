# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
model = load_model('/content/gdrive/MyDrive/Colab Dataset/model_vgg16_70-30.h5')

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  # predict images

  path = '/content/' + fn
  img = image.load_img(path, target_size=(224,224))

  x = image.img_to_array(img)
  x = np.expand_dims(x,axis=0)
  img_data = np.vstack([x])
  classes = model.predict(img_data, batch_size=10)

  print(classes[0])
  
  if classes[(0,1)]>0.5:
    print(fn + ' is pneumonia')
    plt.imshow(img)
  else:
    print(fn + ' is normal')
    plt.imshow(img)
# Out:
#      <input type="file" id="files-3534b3f1-8675-47e3-a3a1-9e18a400d415" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3534b3f1-8675-47e3-a3a1-9e18a400d415">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NORMAL2-IM-1436-0001.jpeg to NORMAL2-IM-1436-0001.jpeg
# [1. 0.]
# NORMAL2-IM-1436-0001.jpeg is normal
